# %%
import os
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator

import matplotlib.pyplot as plt

import time 

from tensorflow.keras.models import Sequential
from tensorflow.keras.applications import DenseNet121
from tensorflow.keras.layers import Flatten, Dense, Dropout

# %%
train_dir = 'data3a/training' 
val_dir = 'data3a/validation'

# %%
img_width, img_height = 150, 150

# %%
epoch = 50
batch_size=16

# %%
train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    shear_range=0.2,
    zoom_range=0.1,
    horizontal_flip=True,
    vertical_flip=True
)

val_datagen = ImageDataGenerator(rescale=1./255)

# %%
train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(img_width, img_height),
    batch_size=batch_size,
    class_mode='categorical'
)

val_generator = val_datagen.flow_from_directory(
    val_dir,
    target_size=(img_width, img_height),
    batch_size=batch_size,
    class_mode='categorical'
)
# Out:
# Found 1383 images belonging to 3 classes.
# Found 248 images belonging to 3 classes.

# %%
densenet121_model = Sequential()
pretrained_model = DenseNet121(
    include_top=False,
    input_shape=(img_width, img_height, 3),
    pooling='max',
    classes=3,
    weights='imagenet'
)
for layer in pretrained_model.layers:
    layer.trainable=False
    
densenet121_model.add(pretrained_model)
densenet121_model.add(Flatten())
densenet121_model.add(Dense(512, activation='relu'))
# minor moderate and severe (3)
densenet121_model.add(Dense(3, activation='softmax'))

# %%
#Model compile
densenet121_model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
from tensorflow.keras.callbacks import CSVLogger

# Define the CSVLogger

log_folder = "traininglog"
log_file_path = f"{log_folder}/densenet121_training_log.csv"

csv_logger = CSVLogger(log_file_path, append=True)

# %%
set_epoch=50
#Model Train 
start_time = time.time()

# Train the model and pass the CSVLogger as a callback
history = densenet121_model.fit(train_generator, epochs=set_epoch, validation_data=val_generator,callbacks=[csv_logger])

end_time = time.time()
elapsed_time = end_time - start_time

print(f"Total training time: {elapsed_time:.2f} seconds")
# Out:
# Epoch 1/50
# 87/87 [==============================] - 68s 713ms/step - loss: 2.1008 - accuracy: 0.4671 - val_loss: 0.9859 - val_accuracy: 0.5484
# Epoch 2/50
# 87/87 [==============================] - 60s 694ms/step - loss: 1.0133 - accuracy: 0.5568 - val_loss: 0.8535 - val_accuracy: 0.6452
# Epoch 3/50
# 87/87 [==============================] - 60s 692ms/step - loss: 0.9014 - accuracy: 0.6117 - val_loss: 0.8294 - val_accuracy: 0.5927
# Epoch 4/50
# 87/87 [==============================] - 60s 696ms/step - loss: 0.8365 - accuracy: 0.6189 - val_loss: 0.7687 - val_accuracy: 0.6411
# Epoch 5/50
# 87/87 [==============================] - 62s 713ms/step - loss: 0.8450 - accuracy: 0.6009 - val_loss: 0.7561 - val_accuracy: 0.6290
# Epoch 6/50
# 87/87 [==============================] - 60s 691ms/step - loss: 0.8562 - accuracy: 0.6052 - val_loss: 0.8345 - val_accuracy: 0.5968
# Epoch 7/50
# 87/87 [==============================] - 60s 691ms/step - loss: 0.8010 - accuracy: 0.6117 - val_loss: 0.6951 - val_accuracy: 0.6492
# Epoch 8/50
# 87/87 [==============================] - 60s 693ms/step - loss: 0.7723 - accuracy: 0.6464 - val_loss: 0.7583 - val_accuracy: 0.6573
# Epoch 9/50
# 87/87 [==============================] - 60s 686ms/step - loss: 0.7682 - accuracy: 0.6276 - val_loss: 0.9059 - val_accuracy: 0.5847
# Epoch 10/50
# 87/87 [==============================] - 59s 684ms/step - loss: 0.7568 - accuracy: 0.6341 - val_loss: 0.6921 - val_accuracy: 0.6613
# Epoch 11/50
# 87/87 [==============================] - 59s 683ms/step - loss: 0.7705 - accuracy: 0.6377 - val_loss: 0.7319 - val_accuracy: 0.6371
# Epoch 12/50
# 87/87 [==============================] - 60s 688ms/step - loss: 0.7616 - accuracy: 0.6443 - val_loss: 0.7056 - val_accuracy: 0.6694
# Epoch 13/50
# 87/87 [==============================] - 59s 675ms/step - loss: 0.7553 - accuracy: 0.6667 - val_loss: 0.6868 - val_accuracy: 0.6774
# Epoch 14/50
# 87/87 [==============================] - 59s 683ms/step - loss: 0.7481 - accuracy: 0.6537 - val_loss: 0.6868 - val_accuracy: 0.6774
# Epoch 15/50
# 87/87 [==============================] - 59s 681ms/step - loss: 0.7562 - accuracy: 0.6457 - val_loss: 0.8763 - val_accuracy: 0.5968
# Epoch 16/50
# 87/87 [==============================] - 59s 680ms/step - loss: 0.7689 - accuracy: 0.6493 - val_loss: 0.6847 - val_accuracy: 0.6573
# Epoch 17/50
# 87/87 [==============================] - 60s 690ms/step - loss: 0.7274 - accuracy: 0.6667 - val_loss: 0.7364 - val_accuracy: 0.6653
# Epoch 18/50
# 87/87 [==============================] - 60s 686ms/step - loss: 0.7369 - accuracy: 0.6645 - val_loss: 0.7215 - val_accuracy: 0.6613
# Epoch 19/50
# 87/87 [==============================] - 60s 689ms/step - loss: 0.7032 - accuracy: 0.6847 - val_loss: 0.8025 - val_accuracy: 0.6169
# Epoch 20/50
# 87/87 [==============================] - 61s 699ms/step - loss: 0.7050 - accuracy: 0.6804 - val_loss: 0.7026 - val_accuracy: 0.6855
# Epoch 21/50
# 87/87 [==============================] - 59s 684ms/step - loss: 0.7101 - accuracy: 0.6623 - val_loss: 0.7151 - val_accuracy: 0.6694
# Epoch 22/50
# 87/87 [==============================] - 59s 681ms/step - loss: 0.7191 - accuracy: 0.6753 - val_loss: 0.6889 - val_accuracy: 0.6573
# Epoch 23/50
# 87/87 [==============================] - 60s 685ms/step - loss: 0.7284 - accuracy: 0.6710 - val_loss: 0.8290 - val_accuracy: 0.5847
# Epoch 24/50
# 87/87 [==============================] - 59s 680ms/step - loss: 0.7166 - accuracy: 0.6580 - val_loss: 0.7382 - val_accuracy: 0.6210
# Epoch 25/50
# 87/87 [==============================] - 59s 683ms/step - loss: 0.6967 - accuracy: 0.6847 - val_loss: 0.7123 - val_accuracy: 0.6815
# Epoch 26/50
# 87/87 [==============================] - 59s 678ms/step - loss: 0.7125 - accuracy: 0.6761 - val_loss: 0.7370 - val_accuracy: 0.6613
# Epoch 27/50
# 87/87 [==============================] - 60s 685ms/step - loss: 0.6979 - accuracy: 0.6920 - val_loss: 0.7537 - val_accuracy: 0.6169
# Epoch 28/50
# 87/87 [==============================] - 60s 685ms/step - loss: 0.6837 - accuracy: 0.6876 - val_loss: 0.7467 - val_accuracy: 0.6452
# Epoch 29/50
# 87/87 [==============================] - 59s 679ms/step - loss: 0.7037 - accuracy: 0.6790 - val_loss: 0.8120 - val_accuracy: 0.6210
# Epoch 30/50
# 87/87 [==============================] - 60s 690ms/step - loss: 0.6997 - accuracy: 0.6811 - val_loss: 0.7823 - val_accuracy: 0.6048
ss
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# accuracy
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()
from sklearn.metrics import f1_score
# # f1 score
# plt.plot(history.history['f1_score'], label='Training F1 Score')
# plt.plot(history.history['val_f1_score'], label='Validation F1 Score')
# plt.xlabel('Epochs')
# plt.ylabel('F1 Score')
# plt.legend()
# plt.show()

# %%
import numpy as np
val_images, val_labels = [], []
class_names = sorted(train_generator.class_indices.keys())
for i in range(len(val_generator)):
    images, labels = val_generator[i]
    val_images.extend(images)
    val_labels.extend(np.argmax(labels, axis=1))


val_images = np.array(val_images)
val_labels = np.array(val_labels)

predictions = densenet121_model.predict(val_images)



from sklearn.metrics import confusion_matrix, classification_report

y_pred = np.argmax(predictions, axis=1)
y_true = val_labels

confusion_matrix = confusion_matrix(y_true, y_pred)
fig, ax = plt.subplots()
cax = ax.matshow(confusion_matrix, cmap='Reds')

cbar = fig.colorbar(cax)

ax.set_xlabel('predicted') #predicted
ax.set_ylabel('actual') #actual

ax.set_xticklabels([''] + ['minor', 'moderate', 'severe'], rotation=45) #predicted
ax.set_yticklabels([''] + ['minor', 'moderate', 'severe']) #actual

for i in range(confusion_matrix.shape[0]):
    for j in range(confusion_matrix.shape[1]):
        ax.text(j, i, str(confusion_matrix[i, j]), ha='center', va='center')
print('Confusion Matrix:')

plt.show()



report = classification_report(y_true, y_pred, target_names=class_names)
print('Classification Report:')
print(report)
# Out:
# 8/8 [==============================] - 10s 1s/step
# Confusion Matrix:
# C:\Users\sandi\AppData\Local\Temp\ipykernel_8220\3449477194.py:31: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels([''] + ['minor', 'moderate', 'severe'], rotation=45) #predicted
# C:\Users\sandi\AppData\Local\Temp\ipykernel_8220\3449477194.py:32: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels([''] + ['minor', 'moderate', 'severe']) #actual
# Classification Report:
#               precision    recall  f1-score   support
#
#     01-minor       0.57      0.76      0.65        82
#  02-moderate       0.36      0.41      0.39        75
#    03-severe       0.84      0.51      0.63        91
#
#     accuracy                           0.56       248
#    macro avg       0.59      0.56      0.56       248
# weighted avg       0.61      0.56      0.56       248

# %%
densenet121_model.save('models/densenet121-model-bs16-ep50.keras')
print('model saved')
# Out:
# model saved

# %%
val_dir = 'data3a/validation'
class_names = ["01-minor", "02-moderate", "03-severe"]

image_paths = []
for class_name in class_names:
    folder_path = os.path.join(val_dir, class_name)
    for filename in os.listdir(folder_path):
        if filename.endswith(".jpg") or filename.endswith(".png"):
            image_paths.append(os.path.join(folder_path, filename))
negative = 0
positive = 0
for image_path in image_paths:
    img = tf.keras.preprocessing.image.load_img(image_path)
    img = img.resize((img_width, img_height))
    img = tf.keras.preprocessing.image.img_to_array(img)
    img = img / 255.0
    img = tf.expand_dims(img, axis=0)
    pred = densenet121_model.predict(img)
    pred_label = class_names[np.argmax(pred)]
    folder_name = os.path.basename(os.path.dirname(image_path))
    plt.imshow(img[0])
    if (pred_label != folder_name):
        plt.title('Pred: ' + pred_label + ' Actl: ' + folder_name, color = 'red')
        negative+=1
    else:
        plt.title('Pred: ' + pred_label + ' Actl: ' + folder_name, color = 'green')
        positive+=1
   
    plt.axis('off')
    plt.show() 
print('False: '+ str(negative) + '\nTrue: ' + str(positive))
