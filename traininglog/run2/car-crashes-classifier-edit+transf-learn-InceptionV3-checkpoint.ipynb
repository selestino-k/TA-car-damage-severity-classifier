# %%
import os
import tensorflow as tf

train_dir = 'data3a/training' 
val_dir = 'data3a/validation'

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications.inception_v3 import preprocess_input

train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    shear_range=0.2,
    zoom_range=0.1,
    horizontal_flip=True,
    vertical_flip=True,
)

val_datagen = ImageDataGenerator(rescale=1./255)

# %%
img_width, img_height = 150, 150
batch_size = 16

# %%
train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(img_width, img_height),
    batch_size=batch_size,
    class_mode='categorical'
)

val_generator = val_datagen.flow_from_directory(
    val_dir,
    target_size=(img_width, img_height),
    batch_size=batch_size,
    class_mode='categorical'
)
# Out:
# Found 1383 images belonging to 3 classes.
# Found 248 images belonging to 3 classes.

# %%
from tensorflow.keras.applications import InceptionV3
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Flatten, Dense, Dropout

inceptionv3_model = Sequential()
pretrained_model = InceptionV3(
    include_top=False,
    input_shape=(img_width, img_height, 3),
    pooling='max',
    classes=3,
    weights='imagenet'
)
for layer in pretrained_model.layers:
    layer.trainable=False
    
inceptionv3_model.add(pretrained_model)

inceptionv3_model.add(Flatten())
inceptionv3_model.add(Dense(512, activation='relu',))
# minor, moderate, and severe (3)
inceptionv3_model.add(Dense(3, activation='softmax'))

# %%
inceptionv3_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  inception_v3 (Functional)   (None, 2048)              21802784
#
#  flatten (Flatten)           (None, 2048)              0
#
#  dense (Dense)               (None, 512)               1049088
#
#  dense_1 (Dense)             (None, 3)                 1539
#
# =================================================================
# Total params: 22853411 (87.18 MB)
# Trainable params: 1050627 (4.01 MB)
# Non-trainable params: 21802784 (83.17 MB)
# _________________________________________________________________

# %%
#Model compile
from tensorflow.keras.optimizers import Adam
opt = Adam(learning_rate=0.001)

inceptionv3_model.compile(optimizer=opt, loss='categorical_crossentropy', metrics=['accuracy'])

# %%
from tensorflow.keras.callbacks import CSVLogger

# Define the CSVLogger

log_folder = "traininglog"
log_file_path = f"{log_folder}/inceptionv3_training_log.csv"

csv_logger = CSVLogger(log_file_path, append=True)

# %%
#Model Train 
set_epoch=50

import time 
start_time = time.time()

# Train the model and pass the CSVLogger as a callback
history = inceptionv3_model.fit(train_generator, epochs=set_epoch, validation_data=val_generator,callbacks=[csv_logger])

end_time = time.time()
elapsed_time = end_time - start_time

print(f"Total training time: {elapsed_time:.2f} seconds")
# Out:
# Epoch 1/50
# 87/87 [==============================] - 27s 261ms/step - loss: 2.6345 - accuracy: 0.4570 - val_loss: 0.7705 - val_accuracy: 0.6532
# Epoch 2/50
# 87/87 [==============================] - 19s 214ms/step - loss: 1.0589 - accuracy: 0.5177 - val_loss: 0.8762 - val_accuracy: 0.5645
# Epoch 3/50
# 87/87 [==============================] - 18s 204ms/step - loss: 0.9909 - accuracy: 0.5170 - val_loss: 0.8977 - val_accuracy: 0.5444
# Epoch 4/50
# 87/87 [==============================] - 18s 204ms/step - loss: 0.9180 - accuracy: 0.5589 - val_loss: 0.8112 - val_accuracy: 0.6331
# Epoch 5/50
# 87/87 [==============================] - 18s 205ms/step - loss: 0.8524 - accuracy: 0.5842 - val_loss: 0.7033 - val_accuracy: 0.7056
# Epoch 6/50
# 87/87 [==============================] - 19s 216ms/step - loss: 0.8812 - accuracy: 0.5582 - val_loss: 0.7039 - val_accuracy: 0.7298
# Epoch 7/50
# 87/87 [==============================] - 19s 215ms/step - loss: 0.8324 - accuracy: 0.5965 - val_loss: 0.7568 - val_accuracy: 0.6653
# Epoch 8/50
# 87/87 [==============================] - 20s 224ms/step - loss: 0.8860 - accuracy: 0.5705 - val_loss: 0.8076 - val_accuracy: 0.6210
# Epoch 9/50
# 87/87 [==============================] - 20s 224ms/step - loss: 0.8543 - accuracy: 0.5871 - val_loss: 0.7278 - val_accuracy: 0.7097
# Epoch 10/50
# 87/87 [==============================] - 19s 223ms/step - loss: 0.8659 - accuracy: 0.5907 - val_loss: 0.7593 - val_accuracy: 0.6492
# Epoch 11/50
# 87/87 [==============================] - 19s 222ms/step - loss: 0.8283 - accuracy: 0.6052 - val_loss: 0.6825 - val_accuracy: 0.7500
# Epoch 12/50
# 87/87 [==============================] - 20s 224ms/step - loss: 0.8270 - accuracy: 0.6175 - val_loss: 0.7017 - val_accuracy: 0.7177
# Epoch 13/50
# 87/87 [==============================] - 20s 235ms/step - loss: 0.8352 - accuracy: 0.6139 - val_loss: 0.7395 - val_accuracy: 0.6774
# Epoch 14/50
# 87/87 [==============================] - 21s 240ms/step - loss: 0.8366 - accuracy: 0.6124 - val_loss: 0.7426 - val_accuracy: 0.6895
# Epoch 15/50
# 87/87 [==============================] - 20s 235ms/step - loss: 0.7990 - accuracy: 0.6349 - val_loss: 0.7016 - val_accuracy: 0.6855
# Epoch 16/50
# 87/87 [==============================] - 20s 225ms/step - loss: 0.8111 - accuracy: 0.6305 - val_loss: 0.7131 - val_accuracy: 0.6815
# Epoch 17/50
# 87/87 [==============================] - 20s 224ms/step - loss: 0.8096 - accuracy: 0.6161 - val_loss: 0.7108 - val_accuracy: 0.7177
# Epoch 18/50
# 87/87 [==============================] - 20s 228ms/step - loss: 0.8192 - accuracy: 0.6197 - val_loss: 0.7583 - val_accuracy: 0.6411
# Epoch 19/50
# 87/87 [==============================] - 20s 227ms/step - loss: 0.7920 - accuracy: 0.6153 - val_loss: 0.7872 - val_accuracy: 0.6290
# Epoch 20/50
# 87/87 [==============================] - 20s 231ms/step - loss: 0.8032 - accuracy: 0.6298 - val_loss: 0.7016 - val_accuracy: 0.7097
# Epoch 21/50
# 87/87 [==============================] - 20s 225ms/step - loss: 0.8103 - accuracy: 0.6103 - val_loss: 0.6893 - val_accuracy: 0.7298
# Epoch 22/50
# 87/87 [==============================] - 20s 226ms/step - loss: 0.7994 - accuracy: 0.6240 - val_loss: 0.6992 - val_accuracy: 0.6935
# Epoch 23/50
# 87/87 [==============================] - 20s 226ms/step - loss: 0.7866 - accuracy: 0.6298 - val_loss: 0.7133 - val_accuracy: 0.7177
# Epoch 24/50
# 87/87 [==============================] - 20s 224ms/step - loss: 0.7979 - accuracy: 0.6247 - val_loss: 0.7113 - val_accuracy: 0.7016
# Epoch 25/50
# 87/87 [==============================] - 20s 225ms/step - loss: 0.7936 - accuracy: 0.6283 - val_loss: 0.6584 - val_accuracy: 0.7218
# Epoch 26/50
# 87/87 [==============================] - 19s 223ms/step - loss: 0.7911 - accuracy: 0.6298 - val_loss: 0.7997 - val_accuracy: 0.6290
# Epoch 27/50
# 87/87 [==============================] - 19s 223ms/step - loss: 0.7762 - accuracy: 0.6435 - val_loss: 0.6515 - val_accuracy: 0.7177
# Epoch 28/50
# 87/87 [==============================] - 19s 223ms/step - loss: 0.8103 - accuracy: 0.6305 - val_loss: 0.6906 - val_accuracy: 0.6815
# Epoch 29/50
# 87/87 [==============================] - 19s 223ms/step - loss: 0.7713 - accuracy: 0.6406 - val_loss: 0.7456 - val_accuracy: 0.6331
# Epoch 30/50
# 87/87 [==============================] - 19s 223ms/step - loss: 0.7972 - accuracy: 0.6255 - val_loss: 0.6809 - val_accuracy: 0.7016
# Epoch 31/50
# 87/87 [==============================] - 19s 223ms/step - loss: 0.7817 - accuracy: 0.6399 - val_loss: 0.7217 - val_accuracy: 0.7097
# Epoch 32/50
# 87/87 [==============================] - 19s 223ms/step - loss: 0.7581 - accuracy: 0.6428 - val_loss: 0.6897 - val_accuracy: 0.6895
# Epoch 33/50
# 87/87 [==============================] - 20s 224ms/step - loss: 0.7829 - accuracy: 0.6320 - val_loss: 0.6636 - val_accuracy: 0.7016
# Epoch 34/50
# 87/87 [==============================] - 19s 221ms/step - loss: 0.8089 - accuracy: 0.6204 - val_loss: 0.7545 - val_accuracy: 0.6653
# Epoch 35/50
# 87/87 [==============================] - 20s 224ms/step - loss: 0.7708 - accuracy: 0.6370 - val_loss: 0.7245 - val_accuracy: 0.6895
# Epoch 36/50
# 87/87 [==============================] - 19s 223ms/step - loss: 0.7682 - accuracy: 0.6399 - val_loss: 0.6826 - val_accuracy: 0.7137
# Epoch 37/50
# 87/87 [==============================] - 19s 222ms/step - loss: 0.7614 - accuracy: 0.6493 - val_loss: 0.6728 - val_accuracy: 0.7258
# Epoch 38/50
# 87/87 [==============================] - 19s 221ms/step - loss: 0.7618 - accuracy: 0.6262 - val_loss: 0.6870 - val_accuracy: 0.7056
# Epoch 39/50
# 87/87 [==============================] - 19s 223ms/step - loss: 0.7360 - accuracy: 0.6746 - val_loss: 0.6792 - val_accuracy: 0.6976
# Epoch 40/50
# 87/87 [==============================] - 19s 224ms/step - loss: 0.7576 - accuracy: 0.6551 - val_loss: 0.6760 - val_accuracy: 0.7137
# Epoch 41/50
# 87/87 [==============================] - 20s 224ms/step - loss: 0.7601 - accuracy: 0.6356 - val_loss: 0.6672 - val_accuracy: 0.7218
# Epoch 42/50
# 87/87 [==============================] - 19s 222ms/step - loss: 0.7752 - accuracy: 0.6508 - val_loss: 0.6921 - val_accuracy: 0.7218
# Epoch 43/50
# 87/87 [==============================] - 19s 221ms/step - loss: 0.7536 - accuracy: 0.6464 - val_loss: 0.6626 - val_accuracy: 0.6935
# Epoch 44/50
# 87/87 [==============================] - 19s 222ms/step - loss: 0.7621 - accuracy: 0.6406 - val_loss: 0.7088 - val_accuracy: 0.6653
# Epoch 45/50
# 87/87 [==============================] - 19s 223ms/step - loss: 0.7595 - accuracy: 0.6392 - val_loss: 0.7605 - val_accuracy: 0.6653
# Epoch 46/50
# 87/87 [==============================] - 19s 223ms/step - loss: 0.7867 - accuracy: 0.6327 - val_loss: 0.6931 - val_accuracy: 0.7056
# Epoch 47/50
# 87/87 [==============================] - 20s 224ms/step - loss: 0.7377 - accuracy: 0.6681 - val_loss: 0.6820 - val_accuracy: 0.7056
# Epoch 48/50
# 87/87 [==============================] - 20s 224ms/step - loss: 0.7836 - accuracy: 0.6529 - val_loss: 0.7479 - val_accuracy: 0.6452
# Epoch 49/50
# 87/87 [==============================] - 19s 222ms/step - loss: 0.7329 - accuracy: 0.6551 - val_loss: 0.7037 - val_accuracy: 0.6774
# Epoch 50/50
# 87/87 [==============================] - 20s 224ms/step - loss: 0.7500 - accuracy: 0.6493 - val_loss: 0.7336 - val_accuracy: 0.6895
# Total training time: 980.14 seconds

# %%
import matplotlib.pyplot as plt

# loss
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# accuracy
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
import numpy as np
val_images, val_labels = [], []
class_names = sorted(train_generator.class_indices.keys())
for i in range(len(val_generator)):
    images, labels = val_generator[i]
    val_images.extend(images)
    val_labels.extend(np.argmax(labels, axis=1))

val_images = np.array(val_images)
val_labels = np.array(val_labels)

predictions = inceptionv3_model.predict(val_images)

y_pred = np.argmax(predictions, axis=1)
y_true = val_labels

from sklearn.metrics import confusion_matrix, classification_report

confusion_matrix = confusion_matrix(y_true, y_pred)
fig, ax = plt.subplots()
cax = ax.matshow(confusion_matrix, cmap='Reds')
    
cbar = fig.colorbar(cax)

ax.set_xlabel('predicted') #predicted
ax.set_ylabel('actual') #actual

ax.set_xticklabels([''] + ['minor', 'moderate', 'severe'], rotation=45) #predicted
ax.set_yticklabels([''] + ['minor', 'moderate', 'severe']) #actual

for i in range(confusion_matrix.shape[0]):
    for j in range(confusion_matrix.shape[1]):
        ax.text(j, i, str(confusion_matrix[i, j]), ha='center', va='center')
print('Confusion Matrix:')

plt.show()

report = classification_report(y_true, y_pred, target_names=class_names)
print('Classification Report:')
print(report)

# %%
val_dir = 'data3a/validation'
class_names = ["01-minor", "02-moderate", "03-severe"]

image_paths = []
for class_name in class_names:
    folder_path = os.path.join(val_dir, class_name)
    for filename in os.listdir(folder_path):
        if filename.endswith(".jpg") or filename.endswith(".png"):
            image_paths.append(os.path.join(folder_path, filename))
negative = 0
positive = 0
for image_path in image_paths:
    img = tf.keras.preprocessing.image.load_img(image_path)
    img = img.resize((img_width, img_height))
    img = tf.keras.preprocessing.image.img_to_array(img)
    img = img / 255.0
    img = tf.expand_dims(img, axis=0)
    pred = inceptionv3_model.predict(img)
    pred_label = class_names[np.argmax(pred)]
    folder_name = os.path.basename(os.path.dirname(image_path))
    plt.imshow(img[0])
    if (pred_label != folder_name):
        plt.title('Pred: ' + pred_label + ' Actl: ' + folder_name, color = 'red')
        negative+=1
    else:
        plt.title('Pred: ' + pred_label + ' Actl: ' + folder_name, color = 'green')
        positive+=1
   
    plt.axis('off')
    plt.show() 
print('False: '+ str(negative) + '\nTrue: ' + str(positive))

# %%
inceptionv3_model.save('models/inceptionv3-model-bs16-ep50-dense512.keras')
print('model saved')
