# %%
import os
import tensorflow as tf

train_dir = 'data3a/training' 
val_dir = 'data3a/validation'

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications.inception_v3 import preprocess_input

train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    shear_range=0.2,
    zoom_range=0.1,
    horizontal_flip=True,
    vertical_flip=True,
)

val_datagen = ImageDataGenerator(rescale=1./255)

# %%
img_width, img_height = 150, 150
batch_size = 16

# %%
train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(img_width, img_height),
    batch_size=batch_size,
    class_mode='categorical'
)

val_generator = val_datagen.flow_from_directory(
    val_dir,
    target_size=(img_width, img_height),
    batch_size=batch_size,
    class_mode='categorical'
)
# Out:
# Found 1383 images belonging to 3 classes.
# Found 248 images belonging to 3 classes.

# %%
from tensorflow.keras.applications import InceptionV3
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Flatten, Dense, Dropout

inceptionv3_model = Sequential()
pretrained_model = InceptionV3(
    include_top=False,
    input_shape=(img_width, img_height, 3),
    pooling='max',
    classes=3,
    weights='imagenet'
)
for layer in pretrained_model.layers:
    layer.trainable=False
    
inceptionv3_model.add(pretrained_model)

inceptionv3_model.add(Flatten())
inceptionv3_model.add(Dense(512, activation='relu',))
# minor, moderate, and severe (3)
inceptionv3_model.add(Dense(3, activation='softmax'))

# %%
inceptionv3_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  inception_v3 (Functional)   (None, 2048)              21802784
#
#  flatten (Flatten)           (None, 2048)              0
#
#  dense (Dense)               (None, 512)               1049088
#
#  dense_1 (Dense)             (None, 3)                 1539
#
# =================================================================
# Total params: 22853411 (87.18 MB)
# Trainable params: 1050627 (4.01 MB)
# Non-trainable params: 21802784 (83.17 MB)
# _________________________________________________________________

# %%
#Model compile
from tensorflow.keras.optimizers import Adam
opt = Adam(learning_rate=0.001)

inceptionv3_model.compile(optimizer=opt, loss='categorical_crossentropy', metrics=['accuracy'])

# %%
from tensorflow.keras.callbacks import CSVLogger

# Define the CSVLogger

log_folder = "traininglog"
log_file_path = f"{log_folder}/inceptionv3_training_log.csv"

csv_logger = CSVLogger(log_file_path, append=True)

# %%
#Model Train 
set_epoch=50

import time 
start_time = time.time()

# Train the model and pass the CSVLogger as a callback
history = inceptionv3_model.fit(train_generator, epochs=set_epoch, validation_data=val_generator,callbacks=[csv_logger])

end_time = time.time()
elapsed_time = end_time - start_time

print(f"Total training time: {elapsed_time:.2f} seconds")
# Out:
# Epoch 1/50
# 87/87 [==============================] - 30s 301ms/step - loss: 2.9324 - accuracy: 0.4447 - val_loss: 1.1434 - val_accuracy: 0.5685
# Epoch 2/50
# 87/87 [==============================] - 26s 294ms/step - loss: 1.1120 - accuracy: 0.5040 - val_loss: 0.8539 - val_accuracy: 0.5887
# Epoch 3/50
# 87/87 [==============================] - 21s 235ms/step - loss: 0.9632 - accuracy: 0.5503 - val_loss: 0.8181 - val_accuracy: 0.6008
# Epoch 4/50
# 87/87 [==============================] - 19s 213ms/step - loss: 0.8981 - accuracy: 0.5712 - val_loss: 0.7441 - val_accuracy: 0.6411
# Epoch 5/50
# 87/87 [==============================] - 18s 210ms/step - loss: 0.9092 - accuracy: 0.5719 - val_loss: 0.7067 - val_accuracy: 0.6855
# Epoch 6/50
# 87/87 [==============================] - 18s 212ms/step - loss: 0.9064 - accuracy: 0.5683 - val_loss: 0.7574 - val_accuracy: 0.6694
# 87/87 [==============================] - 19s 215ms/step - loss: 0.8017 - accuracy: 0.6298 - val_loss: 0.7166 - val_accuracy: 0.7016
# Epoch 26/50
# 87/87 [==============================] - 20s 228ms/step - loss: 0.7966 - accuracy: 0.6255 - val_loss: 0.7817 - val_accuracy: 0.6532
# Epoch 27/50
# 87/87 [==============================] - 20s 226ms/step - loss: 0.7920 - accuracy: 0.6327 - val_loss: 0.7582 - val_accuracy: 0.6532
# Epoch 28/50
# 87/87 [==============================] - 20s 225ms/step - loss: 0.7680 - accuracy: 0.6320 - val_loss: 0.7809 - val_accuracy: 0.6331
# Epoch 29/50
# 87/87 [==============================] - 19s 222ms/step - loss: 0.7901 - accuracy: 0.6247 - val_loss: 0.8191 - val_accuracy: 0.6210
# Epoch 30/50
# 87/87 [==============================] - 20s 224ms/step - loss: 0.7882 - accuracy: 0.6334 - val_loss: 0.6845 - val_accuracy: 0.7177
# Epoch 31/50
# 87/87 [==============================] - 20s 226ms/step - loss: 0.7606 - accuracy: 0.6414 - val_loss: 0.6817 - val_accuracy: 0.7137
# Epoch 32/50
# 87/87 [==============================] - 20s 224ms/step - loss: 0.7799 - accuracy: 0.6240 - val_loss: 0.6532 - val_accuracy: 0.7137
# Epoch 33/50
# 87/87 [==============================] - 20s 224ms/step - loss: 0.7514 - accuracy: 0.6479 - val_loss: 0.6593 - val_accuracy: 0.7339
# Epoch 34/50
# 87/87 [==============================] - 20s 225ms/step - loss: 0.7796 - accuracy: 0.6341 - val_loss: 0.6600 - val_accuracy: 0.7419
# Epoch 35/50
# 87/87 [==============================] - 24s 273ms/step - loss: 0.7656 - accuracy: 0.6551 - val_loss: 0.7631 - val_accuracy: 0.6129
# Epoch 36/50
# 87/87 [==============================] - 22s 253ms/step - loss: 0.7683 - accuracy: 0.6406 - val_loss: 0.7265 - val_accuracy: 0.6774
# Epoch 37/50
# 87/87 [==============================] - 18s 207ms/step - loss: 0.7623 - accuracy: 0.6551 - val_loss: 0.6672 - val_accuracy: 0.7137
# Epoch 38/50
# 87/87 [==============================] - 18s 202ms/step - loss: 0.7663 - accuracy: 0.6392 - val_loss: 0.6655 - val_accuracy: 0.7016
# Epoch 39/50
# 87/87 [==============================] - 18s 203ms/step - loss: 0.7877 - accuracy: 0.6283 - val_loss: 0.7140 - val_accuracy: 0.6613
# Epoch 40/50
# 87/87 [==============================] - 18s 207ms/step - loss: 0.7511 - accuracy: 0.6471 - val_loss: 0.6933 - val_accuracy: 0.6935
# Epoch 41/50
# 87/87 [==============================] - 18s 210ms/step - loss: 0.7585 - accuracy: 0.6450 - val_loss: 0.7697 - val_accuracy: 0.6331
# Epoch 42/50
# 87/87 [==============================] - 20s 228ms/step - loss: 0.7607 - accuracy: 0.6457 - val_loss: 0.6891 - val_accuracy: 0.6976
# Epoch 43/50
# 87/87 [==============================] - 20s 227ms/step - loss: 0.7600 - accuracy: 0.6486 - val_loss: 0.6918 - val_accuracy: 0.6935
# Epoch 44/50
# 87/87 [==============================] - 20s 225ms/step - loss: 0.7837 - accuracy: 0.6291 - val_loss: 0.6715 - val_accuracy: 0.7016
# Epoch 45/50
# 87/87 [==============================] - 20s 224ms/step - loss: 0.7366 - accuracy: 0.6696 - val_loss: 0.6791 - val_accuracy: 0.6976
# Epoch 46/50
# 87/87 [==============================] - 19s 223ms/step - loss: 0.7444 - accuracy: 0.6602 - val_loss: 0.7116 - val_accuracy: 0.6694
# Epoch 47/50
# 87/87 [==============================] - 20s 224ms/step - loss: 0.7557 - accuracy: 0.6493 - val_loss: 0.7181 - val_accuracy: 0.6774
# Epoch 48/50
# 87/87 [==============================] - 20s 224ms/step - loss: 0.7946 - accuracy: 0.6450 - val_loss: 0.7414 - val_accuracy: 0.6774
# Epoch 49/50
# 87/87 [==============================] - 20s 226ms/step - loss: 0.7724 - accuracy: 0.6464 - val_loss: 0.7048 - val_accuracy: 0.6734
# Epoch 50/50
# 87/87 [==============================] - 20s 226ms/step - loss: 0.7437 - accuracy: 0.6428 - val_loss: 0.7329 - val_accuracy: 0.6815
# Total training time: 988.89 seconds

# %%
import matplotlib.pyplot as plt

# loss
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# accuracy
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
import numpy as np
val_images, val_labels = [], []
class_names = sorted(train_generator.class_indices.keys())
for i in range(len(val_generator)):
    images, labels = val_generator[i]
    val_images.extend(images)
    val_labels.extend(np.argmax(labels, axis=1))

val_images = np.array(val_images)
val_labels = np.array(val_labels)

predictions = inceptionv3_model.predict(val_images)

y_pred = np.argmax(predictions, axis=1)
y_true = val_labels

from sklearn.metrics import confusion_matrix, classification_report

confusion_matrix = confusion_matrix(y_true, y_pred)
fig, ax = plt.subplots()
cax = ax.matshow(confusion_matrix, cmap='Reds')
    
cbar = fig.colorbar(cax)

ax.set_xlabel('predicted') #predicted
ax.set_ylabel('actual') #actual

ax.set_xticklabels([''] + ['minor', 'moderate', 'severe'], rotation=45) #predicted
ax.set_yticklabels([''] + ['minor', 'moderate', 'severe']) #actual

for i in range(confusion_matrix.shape[0]):
    for j in range(confusion_matrix.shape[1]):
        ax.text(j, i, str(confusion_matrix[i, j]), ha='center', va='center')
print('Confusion Matrix:')

plt.show()

report = classification_report(y_true, y_pred, target_names=class_names)
print('Classification Report:')
print(report)

# %%
val_dir = 'data3a/validation'
class_names = ["01-minor", "02-moderate", "03-severe"]

image_paths = []
for class_name in class_names:
    folder_path = os.path.join(val_dir, class_name)
    for filename in os.listdir(folder_path):
        if filename.endswith(".jpg") or filename.endswith(".png"):
            image_paths.append(os.path.join(folder_path, filename))
negative = 0
positive = 0
for image_path in image_paths:
    img = tf.keras.preprocessing.image.load_img(image_path)
    img = img.resize((img_width, img_height))
    img = tf.keras.preprocessing.image.img_to_array(img)
    img = img / 255.0
    img = tf.expand_dims(img, axis=0)
    pred = inceptionv3_model.predict(img)
    pred_label = class_names[np.argmax(pred)]
    folder_name = os.path.basename(os.path.dirname(image_path))
    plt.imshow(img[0])
    if (pred_label != folder_name):
        plt.title('Pred: ' + pred_label + ' Actl: ' + folder_name, color = 'red')
        negative+=1
    else:
        plt.title('Pred: ' + pred_label + ' Actl: ' + folder_name, color = 'green')
        positive+=1
   
    plt.axis('off')
    plt.show() 
print('False: '+ str(negative) + '\nTrue: ' + str(positive))

# %%
inceptionv3_model.save('models/inceptionv3-model-bs16-ep50-dense512.keras')
print('model saved')
