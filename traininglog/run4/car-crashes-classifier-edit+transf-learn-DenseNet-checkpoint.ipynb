# %%
import os
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator

import matplotlib.pyplot as plt

import time 

from tensorflow.keras.models import Sequential
from tensorflow.keras.applications import DenseNet121
from tensorflow.keras.layers import Flatten, Dense, Dropout

# %%
train_dir = 'data3a/training' 
val_dir = 'data3a/validation'

# %%
img_width, img_height = 150, 150

# %%
epoch = 50
batch_size=16

# %%
train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    shear_range=0.2,
    zoom_range=0.1,
    horizontal_flip=True,
    vertical_flip=True
)

val_datagen = ImageDataGenerator(rescale=1./255)

# %%
train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(img_width, img_height),
    batch_size=batch_size,
    class_mode='categorical'
)

val_generator = val_datagen.flow_from_directory(
    val_dir,
    target_size=(img_width, img_height),
    batch_size=batch_size,
    class_mode='categorical'
)
# Out:
# Found 1383 images belonging to 3 classes.
# Found 248 images belonging to 3 classes.

# %%
densenet121_model = Sequential()
pretrained_model = DenseNet121(
    include_top=False,
    input_shape=(img_width, img_height, 3),
    pooling='max',
    classes=3,
    weights='imagenet'
)
for layer in pretrained_model.layers:
    layer.trainable=False
    
densenet121_model.add(pretrained_model)
densenet121_model.add(Flatten())
densenet121_model.add(Dense(512, activation='relu'))
# minor moderate and severe (3)
densenet121_model.add(Dense(3, activation='softmax'))

# %%
#Model compile
densenet121_model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
from tensorflow.keras.callbacks import CSVLogger

# Define the CSVLogger

log_folder = "traininglog"
log_file_path = f"{log_folder}/densenet121_training_log.csv"

csv_logger = CSVLogger(log_file_path, append=True)

# %%
#### set_epoch=50
#Model Train 
start_time = time.time()

# Train the model and pass the CSVLogger as a callback
history = densenet121_model.fit(train_generator, epochs=set_epoch, validation_data=val_generator,callbacks=[csv_logger])

end_time = time.time()
elapsed_time = end_time - start_time

print(f"Total training time: {elapsed_time:.2f} seconds")
# Out:
# Epoch 1/50
# 87/87 [==============================] - 67s 701ms/step - loss: 2.2654 - accuracy: 0.4707 - val_loss: 0.9708 - val_accuracy: 0.5524
# Epoch 2/50
# 87/87 [==============================] - 58s 672ms/step - loss: 0.9896 - accuracy: 0.5409 - val_loss: 0.9125 - val_accuracy: 0.5363
# Epoch 3/50
# 87/87 [==============================] - 59s 674ms/step - loss: 0.8886 - accuracy: 0.5857 - val_loss: 0.8915 - val_accuracy: 0.5444
# Epoch 4/50
# 87/87 [==============================] - 59s 684ms/step - loss: 0.8227 - accuracy: 0.5987 - val_loss: 0.7338 - val_accuracy: 0.6290
# Epoch 5/50
# 87/87 [==============================] - 58s 668ms/step - loss: 0.8165 - accuracy: 0.6030 - val_loss: 0.7380 - val_accuracy: 0.6492
# Epoch 6/50
# 87/87 [==============================] - 58s 670ms/step - loss: 0.8028 - accuracy: 0.6291 - val_loss: 0.9158 - val_accuracy: 0.5363
# Epoch 7/50
# 87/87 [==============================] - 59s 675ms/step - loss: 0.7873 - accuracy: 0.6269 - val_loss: 0.7759 - val_accuracy: 0.6048
# Epoch 8/50
# 87/87 [==============================] - 59s 683ms/step - loss: 0.7777 - accuracy: 0.6464 - val_loss: 0.6893 - val_accuracy: 0.6815
# Epoch 9/50
# 87/87 [==============================] - 58s 672ms/step - loss: 0.7938 - accuracy: 0.6269 - val_loss: 0.7251 - val_accuracy: 0.6734
# Epoch 10/50
# 87/87 [==============================] - 53s 608ms/step - loss: 0.7790 - accuracy: 0.6334 - val_loss: 0.7703 - val_accuracy: 0.6129
# Epoch 11/50
# 87/87 [==============================] - 49s 567ms/step - loss: 0.7588 - accuracy: 0.6435 - val_loss: 0.7333 - val_accuracy: 0.6250
# Epoch 12/50
# Epoch 31/50
# 87/87 [==============================] - 47s 536ms/step - loss: 0.6645 - accuracy: 0.6956 - val_loss: 0.7136 - val_accuracy: 0.6774
# Epoch 32/50
# 87/87 [==============================] - 47s 540ms/step - loss: 0.6585 - accuracy: 0.6941 - val_loss: 0.8049 - val_accuracy: 0.6169
# Epoch 33/50
# 87/87 [==============================] - 47s 537ms/step - loss: 0.6514 - accuracy: 0.6999 - val_loss: 0.7886 - val_accuracy: 0.6331
# Epoch 34/50
# 87/87 [==============================] - 49s 565ms/step - loss: 0.6367 - accuracy: 0.7195 - val_loss: 0.7490 - val_accuracy: 0.6532
# Epoch 35/50
# 87/87 [==============================] - 49s 569ms/step - loss: 0.6508 - accuracy: 0.7158 - val_loss: 0.7596 - val_accuracy: 0.6532
# Epoch 36/50
# 87/87 [==============================] - 50s 574ms/step - loss: 0.6450 - accuracy: 0.7108 - val_loss: 0.8844 - val_accuracy: 0.6169
# Epoch 37/50
# 87/87 [==============================] - 48s 554ms/step - loss: 0.6536 - accuracy: 0.7035 - val_loss: 0.9021 - val_accuracy: 0.6210
# Epoch 38/50
# 87/87 [==============================] - 48s 554ms/step - loss: 0.6290 - accuracy: 0.7086 - val_loss: 1.0613 - val_accuracy: 0.5685
# Epoch 39/50
# 87/87 [==============================] - 47s 539ms/step - loss: 0.6450 - accuracy: 0.7209 - val_loss: 0.8173 - val_accuracy: 0.6532
# Epoch 40/50
# 87/87 [==============================] - 47s 545ms/step - loss: 0.6073 - accuracy: 0.7216 - val_loss: 0.7789 - val_accuracy: 0.6613
# Epoch 41/50
# 87/87 [==============================] - 47s 541ms/step - loss: 0.6134 - accuracy: 0.7433 - val_loss: 0.8778 - val_accuracy: 0.5927
# Epoch 42/50
# 87/87 [==============================] - 46s 534ms/step - loss: 0.6321 - accuracy: 0.7231 - val_loss: 0.9367 - val_accuracy: 0.5927
# Epoch 43/50
# 87/87 [==============================] - 46s 527ms/step - loss: 0.5875 - accuracy: 0.7383 - val_loss: 0.8575 - val_accuracy: 0.6250
# Epoch 44/50
# 87/87 [==============================] - 46s 526ms/step - loss: 0.6058 - accuracy: 0.7216 - val_loss: 0.7452 - val_accuracy: 0.6815
# Epoch 45/50
# 87/87 [==============================] - 46s 530ms/step - loss: 0.6130 - accuracy: 0.7325 - val_loss: 0.7352 - val_accuracy: 0.6492
# Epoch 46/50
# 87/87 [==============================] - 46s 533ms/step - loss: 0.6290 - accuracy: 0.7202 - val_loss: 0.8071 - val_accuracy: 0.6048
# Epoch 47/50
# 87/87 [==============================] - 47s 540ms/step - loss: 0.6090 - accuracy: 0.7390 - val_loss: 0.8188 - val_accuracy: 0.6210
# Epoch 48/50
# 87/87 [==============================] - 47s 545ms/step - loss: 0.6177 - accuracy: 0.7274 - val_loss: 0.8810 - val_accuracy: 0.6371
# Epoch 49/50
# 87/87 [==============================] - 47s 535ms/step - loss: 0.5865 - accuracy: 0.7346 - val_loss: 0.8140 - val_accuracy: 0.6250
# Epoch 50/50
# 87/87 [==============================] - 46s 534ms/step - loss: 0.5724 - accuracy: 0.7426 - val_loss: 0.8156 - val_accuracy: 0.6411
# Total training time: 2473.09 seconds

# %%
import matplotlib.pyplot as plt
# loss
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# accuracy
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()
from sklearn.metrics import f1_score
# # f1 score
# plt.plot(history.history['f1_score'], label='Training F1 Score')
# plt.plot(history.history['val_f1_score'], label='Validation F1 Score')
# plt.xlabel('Epochs')
# plt.ylabel('F1 Score')
# plt.legend()
# plt.show()

# %%
import numpy as np
val_images, val_labels = [], []
class_names = sorted(train_generator.class_indices.keys())
for i in range(len(val_generator)):
    images, labels = val_generator[i]
    val_images.extend(images)
    val_labels.extend(np.argmax(labels, axis=1))


val_images = np.array(val_images)
val_labels = np.array(val_labels)

predictions = densenet121_model.predict(val_images)



from sklearn.metrics import confusion_matrix, classification_report

y_pred = np.argmax(predictions, axis=1)
y_true = val_labels

confusion_matrix = confusion_matrix(y_true, y_pred)
fig, ax = plt.subplots()
cax = ax.matshow(confusion_matrix, cmap='Reds')

cbar = fig.colorbar(cax)

ax.set_xlabel('predicted') #predicted
ax.set_ylabel('actual') #actual

ax.set_xticklabels([''] + ['minor', 'moderate', 'severe'], rotation=45) #predicted
ax.set_yticklabels([''] + ['minor', 'moderate', 'severe']) #actual

for i in range(confusion_matrix.shape[0]):
    for j in range(confusion_matrix.shape[1]):
        ax.text(j, i, str(confusion_matrix[i, j]), ha='center', va='center')
print('Confusion Matrix:')

plt.show()



report = classification_report(y_true, y_pred, target_names=class_names)
print('Classification Report:')
print(report)
# Out:
# 8/8 [==============================] - 9s 823ms/step
# Confusion Matrix:
# C:\Users\sandi\AppData\Local\Temp\ipykernel_18256\3449477194.py:31: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels([''] + ['minor', 'moderate', 'severe'], rotation=45) #predicted
# C:\Users\sandi\AppData\Local\Temp\ipykernel_18256\3449477194.py:32: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels([''] + ['minor', 'moderate', 'severe']) #actual
# Classification Report:
#               precision    recall  f1-score   support
#
#     01-minor       0.66      0.73      0.69        82
#  02-moderate       0.47      0.55      0.51        75
#    03-severe       0.83      0.64      0.72        91
#
#     accuracy                           0.64       248
#    macro avg       0.65      0.64      0.64       248
# weighted avg       0.66      0.64      0.65       248

# %%
densenet_model.save('densenet121-model.keras')
print('model saved')

# %%
val_dir = 'data3a/validation'
class_names = ["01-minor", "02-moderate", "03-severe"]

image_paths = []
for class_name in class_names:
    folder_path = os.path.join(val_dir, class_name)
    for filename in os.listdir(folder_path):
        if filename.endswith(".jpg") or filename.endswith(".png"):
            image_paths.append(os.path.join(folder_path, filename))
negative = 0
positive = 0
for image_path in image_paths:
    img = tf.keras.preprocessing.image.load_img(image_path)
    img = img.resize((img_width, img_height))
    img = tf.keras.preprocessing.image.img_to_array(img)
    img = img / 255.0
    img = tf.expand_dims(img, axis=0)
    pred = densenet121_model.predict(img)
    pred_label = class_names[np.argmax(pred)]
    folder_name = os.path.basename(os.path.dirname(image_path))
    plt.imshow(img[0])
    if (pred_label != folder_name):
        plt.title('Pred: ' + pred_label + ' Actl: ' + folder_name, color = 'red')
        negative+=1
    else:
        plt.title('Pred: ' + pred_label + ' Actl: ' + folder_name, color = 'green')
        positive+=1
   
    plt.axis('off')
    plt.show() 
print('False: '+ str(negative) + '\nTrue: ' + str(positive))
