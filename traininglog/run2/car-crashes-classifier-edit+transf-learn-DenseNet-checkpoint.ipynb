# %%
import os
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator

import matplotlib.pyplot as plt

import time 

from tensorflow.keras.models import Sequential
from tensorflow.keras.applications import DenseNet121
from tensorflow.keras.layers import Flatten, Dense, Dropout

# %%
train_dir = 'data3a/training' 
val_dir = 'data3a/validation'

# %%
img_width, img_height = 150, 150

# %%
epoch = 50
batch_size=16

# %%
train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    shear_range=0.2,
    zoom_range=0.1,
    horizontal_flip=True,
    vertical_flip=True
)

val_datagen = ImageDataGenerator(rescale=1./255)

# %%
train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(img_width, img_height),
    batch_size=batch_size,
    class_mode='categorical'
)

val_generator = val_datagen.flow_from_directory(
    val_dir,
    target_size=(img_width, img_height),
    batch_size=batch_size,
    class_mode='categorical'
)
# Out:
# Found 1383 images belonging to 3 classes.
# Found 248 images belonging to 3 classes.

# %%
densenet121_model = Sequential()
pretrained_model = DenseNet121(
    include_top=False,
    input_shape=(img_width, img_height, 3),
    pooling='max',
    classes=3,
    weights='imagenet'
)
for layer in pretrained_model.layers:
    layer.trainable=False
    
densenet121_model.add(pretrained_model)
densenet121_model.add(Flatten())
densenet121_model.add(Dense(512, activation='relu'))
# minor moderate and severe (3)
densenet121_model.add(Dense(3, activation='softmax'))

# %%
#Model compile
densenet121_model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
from tensorflow.keras.callbacks import CSVLogger

# Define the CSVLogger

log_folder = "traininglog"
log_file_path = f"{log_folder}/densenet121_training_log.csv"

csv_logger = CSVLogger(log_file_path, append=True)

# %%
set_epoch=50
#Model Train 
start_time = time.time()

# Train the model and pass the CSVLogger as a callback
history = densenet121_model.fit(train_generator, epochs=set_epoch, validation_data=val_generator,callbacks=[csv_logger])

end_time = time.time()
elapsed_time = end_time - start_time

print(f"Total training time: {elapsed_time:.2f} seconds")
# Out:
# Epoch 1/50
# 87/87 [==============================] - 50s 508ms/step - loss: 1.8360 - accuracy: 0.4881 - val_loss: 1.0809 - val_accuracy: 0.5484
# Epoch 2/50
# 87/87 [==============================] - 42s 486ms/step - loss: 0.9596 - accuracy: 0.5705 - val_loss: 1.0053 - val_accuracy: 0.5766
# Epoch 3/50
# 87/87 [==============================] - 42s 485ms/step - loss: 0.8857 - accuracy: 0.5915 - val_loss: 0.8357 - val_accuracy: 0.5887
# Epoch 4/50
# 87/87 [==============================] - 42s 484ms/step - loss: 0.8157 - accuracy: 0.6124 - val_loss: 0.7528 - val_accuracy: 0.6210
# Epoch 5/50
# 87/87 [==============================] - 42s 485ms/step - loss: 0.7927 - accuracy: 0.6226 - val_loss: 0.7196 - val_accuracy: 0.6371
# Epoch 6/50
# 87/87 [==============================] - 42s 487ms/step - loss: 0.8210 - accuracy: 0.6168 - val_loss: 0.7952 - val_accuracy: 0.6008
# Epoch 7/50
# 87/87 [==============================] - 42s 487ms/step - loss: 0.7884 - accuracy: 0.6233 - val_loss: 0.7594 - val_accuracy: 0.6532
# Epoch 8/50
# 87/87 [==============================] - 42s 485ms/step - loss: 0.7879 - accuracy: 0.6414 - val_loss: 0.7150 - val_accuracy: 0.6250
# Epoch 9/50
# 87/87 [==============================] - 42s 482ms/step - loss: 0.7590 - accuracy: 0.6529 - val_loss: 0.7187 - val_accuracy: 0.6653
# Epoch 10/50
# 87/87 [==============================] - 42s 482ms/step - loss: 0.7597 - accuracy: 0.6522 - val_loss: 0.7327 - val_accuracy: 0.6331
# Epoch 11/50
# 87/87 [==============================] - 42s 481ms/step - loss: 0.7568 - accuracy: 0.6500 - val_loss: 0.6847 - val_accuracy: 0.6734
# Epoch 12/50
# 87/87 [==============================] - 42s 483ms/step - loss: 0.7495 - accuracy: 0.6580 - val_loss: 0.6896 - val_accuracy: 0.6855
# Epoch 13/50
# 87/87 [==============================] - 42s 484ms/step - loss: 0.7544 - accuracy: 0.6544 - val_loss: 0.7743 - val_accuracy: 0.6089
# Epoch 14/50
# 87/87 [==============================] - 42s 480ms/step - loss: 0.7376 - accuracy: 0.6616 - val_loss: 0.7236 - val_accuracy: 0.6653
# Epoch 15/50
# 87/87 [==============================] - 42s 478ms/step - loss: 0.7298 - accuracy: 0.6587 - val_loss: 0.7790 - val_accuracy: 0.6250
# Epoch 16/50
# 87/87 [==============================] - 42s 480ms/step - loss: 0.7262 - accuracy: 0.6688 - val_loss: 0.6994 - val_accuracy: 0.6532
# Epoch 17/50
# 87/87 [==============================] - 43s 498ms/step - loss: 0.7354 - accuracy: 0.6580 - val_loss: 0.6982 - val_accuracy: 0.6653
# Epoch 18/50
# 87/87 [==============================] - 44s 507ms/step - loss: 0.7210 - accuracy: 0.6659 - val_loss: 0.7341 - val_accuracy: 0.6573
# Epoch 19/50
# 87/87 [==============================] - 42s 481ms/step - loss: 0.6889 - accuracy: 0.6826 - val_loss: 0.7920 - val_accuracy: 0.6290
# Epoch 20/50
# 87/87 [==============================] - 43s 490ms/step - loss: 0.7168 - accuracy: 0.6840 - val_loss: 0.8343 - val_accuracy: 0.6331
# Epoch 21/50
# 87/87 [==============================] - 44s 509ms/step - loss: 0.6774 - accuracy: 0.6956 - val_loss: 0.7368 - val_accuracy: 0.6331
# Epoch 22/50
# 87/87 [==============================] - 44s 510ms/step - loss: 0.7268 - accuracy: 0.6703 - val_loss: 0.7221 - val_accuracy: 0.6653
# Epoch 23/50
# 87/87 [==============================] - 44s 511ms/step - loss: 0.7064 - accuracy: 0.6884 - val_loss: 0.9711 - val_accuracy: 0.5847
# Epoch 24/50
# 87/87 [==============================] - 44s 504ms/step - loss: 0.7161 - accuracy: 0.6761 - val_loss: 0.7956 - val_accuracy: 0.6008
# Epoch 25/50
# 87/87 [==============================] - 44s 506ms/step - loss: 0.6991 - accuracy: 0.6790 - val_loss: 0.7729 - val_accuracy: 0.6532
# Epoch 26/50
# 87/87 [==============================] - 44s 509ms/step - loss: 0.6743 - accuracy: 0.7043 - val_loss: 0.7126 - val_accuracy: 0.6694
# Epoch 27/50
# 87/87 [==============================] - 44s 512ms/step - loss: 0.6937 - accuracy: 0.6855 - val_loss: 0.7937 - val_accuracy: 0.6169
# Epoch 28/50
# 87/87 [==============================] - 44s 508ms/step - loss: 0.6952 - accuracy: 0.6732 - val_loss: 0.6938 - val_accuracy: 0.6492
# Epoch 29/50
# 87/87 [==============================] - 44s 508ms/step - loss: 0.6926 - accuracy: 0.6963 - val_loss: 0.7569 - val_accuracy: 0.6573
# Epoch 30/50
# 87/87 [==============================] - 44s 511ms/step - loss: 0.6737 - accuracy: 0.6891 - val_loss: 0.7210 - val_accuracy: 0.6895
# Epoch 31/50
# 87/87 [==============================] - 44s 510ms/step - loss: 0.6587 - accuracy: 0.7007 - val_loss: 0.7784 - val_accuracy: 0.6129
# Epoch 32/50
# 87/87 [==============================] - 44s 508ms/step - loss: 0.6808 - accuracy: 0.6920 - val_loss: 0.7154 - val_accuracy: 0.6895
# Epoch 33/50
# 87/87 [==============================] - 44s 510ms/step - loss: 0.6315 - accuracy: 0.7252 - val_loss: 0.8273 - val_accuracy: 0.6129
# Epoch 34/50
# 87/87 [==============================] - 44s 510ms/step - loss: 0.6549 - accuracy: 0.6956 - val_loss: 0.7250 - val_accuracy: 0.6532
# Epoch 35/50
# 87/87 [==============================] - 43s 491ms/step - loss: 0.6422 - accuracy: 0.7057 - val_loss: 0.8262 - val_accuracy: 0.6613
# Epoch 36/50
# 87/87 [==============================] - 42s 482ms/step - loss: 0.6310 - accuracy: 0.7072 - val_loss: 0.8909 - val_accuracy: 0.6169
# Epoch 37/50
# 87/87 [==============================] - 41s 466ms/step - loss: 0.6365 - accuracy: 0.7115 - val_loss: 0.8293 - val_accuracy: 0.5927
# Epoch 38/50
# 87/87 [==============================] - 42s 479ms/step - loss: 0.6287 - accuracy: 0.7129 - val_loss: 0.7290 - val_accuracy: 0.6452
# Epoch 39/50
# 87/87 [==============================] - 43s 495ms/step - loss: 0.6099 - accuracy: 0.7281 - val_loss: 0.7088 - val_accuracy: 0.6855
# Epoch 40/50
# 87/87 [==============================] - 42s 478ms/step - loss: 0.6292 - accuracy: 0.7368 - val_loss: 0.8971 - val_accuracy: 0.5968
# Epoch 41/50
# 87/87 [==============================] - 42s 487ms/step - loss: 0.6122 - accuracy: 0.7375 - val_loss: 0.7292 - val_accuracy: 0.6613
# Epoch 42/50
# 87/87 [==============================] - 43s 493ms/step - loss: 0.6040 - accuracy: 0.7303 - val_loss: 0.7800 - val_accuracy: 0.6653
# Epoch 43/50
# 87/87 [==============================] - 41s 470ms/step - loss: 0.6275 - accuracy: 0.7195 - val_loss: 0.7713 - val_accuracy: 0.6290
# Epoch 44/50
# 87/87 [==============================] - 41s 473ms/step - loss: 0.5957 - accuracy: 0.7448 - val_loss: 0.7554 - val_accuracy: 0.6290
# Epoch 45/50
# 87/87 [==============================] - 43s 492ms/step - loss: 0.5792 - accuracy: 0.7426 - val_loss: 0.9227 - val_accuracy: 0.6008
# Epoch 46/50
# 87/87 [==============================] - 43s 490ms/step - loss: 0.6138 - accuracy: 0.7166 - val_loss: 0.7873 - val_accuracy: 0.6774
# Epoch 47/50
# 87/87 [==============================] - 42s 483ms/step - loss: 0.6196 - accuracy: 0.7252 - val_loss: 0.7531 - val_accuracy: 0.6532
# Epoch 48/50
# 87/87 [==============================] - 42s 486ms/step - loss: 0.5811 - accuracy: 0.7462 - val_loss: 0.7316 - val_accuracy: 0.7016
# Epoch 49/50
# 87/87 [==============================] - 41s 475ms/step - loss: 0.5803 - accuracy: 0.7455 - val_loss: 0.8562 - val_accuracy: 0.6169
# Epoch 50/50
# 87/87 [==============================] - 42s 486ms/step - loss: 0.6087 - accuracy: 0.7397 - val_loss: 0.8231 - val_accuracy: 0.6048
# Total training time: 2146.41 seconds

# %%
import matplotlib.pyplot as plt
# loss
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# accuracy
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()
from sklearn.metrics import f1_score
# # f1 score
# plt.plot(history.history['f1_score'], label='Training F1 Score')
# plt.plot(history.history['val_f1_score'], label='Validation F1 Score')
# plt.xlabel('Epochs')
# plt.ylabel('F1 Score')
# plt.legend()
# plt.show()

# %%
import numpy as np
val_images, val_labels = [], []
class_names = sorted(train_generator.class_indices.keys())
for i in range(len(val_generator)):
    images, labels = val_generator[i]
    val_images.extend(images)
    val_labels.extend(np.argmax(labels, axis=1))


val_images = np.array(val_images)
val_labels = np.array(val_labels)

predictions = densenet121_model.predict(val_images)



from sklearn.metrics import confusion_matrix, classification_report

y_pred = np.argmax(predictions, axis=1)
y_true = val_labels

confusion_matrix = confusion_matrix(y_true, y_pred)
fig, ax = plt.subplots()
cax = ax.matshow(confusion_matrix, cmap='Reds')

cbar = fig.colorbar(cax)

ax.set_xlabel('predicted') #predicted
ax.set_ylabel('actual') #actual

ax.set_xticklabels([''] + ['minor', 'moderate', 'severe'], rotation=45) #predicted
ax.set_yticklabels([''] + ['minor', 'moderate', 'severe']) #actual

for i in range(confusion_matrix.shape[0]):
    for j in range(confusion_matrix.shape[1]):
        ax.text(j, i, str(confusion_matrix[i, j]), ha='center', va='center')
print('Confusion Matrix:')

plt.show()



report = classification_report(y_true, y_pred, target_names=class_names)
print('Classification Report:')
print(report)

# %%
densenet_model.save('densenet121-model.keras')
print('model saved')

# %%
val_dir = 'data3a/validation'
class_names = ["01-minor", "02-moderate", "03-severe"]

image_paths = []
for class_name in class_names:
    folder_path = os.path.join(val_dir, class_name)
    for filename in os.listdir(folder_path):
        if filename.endswith(".jpg") or filename.endswith(".png"):
            image_paths.append(os.path.join(folder_path, filename))
negative = 0
positive = 0
for image_path in image_paths:
    img = tf.keras.preprocessing.image.load_img(image_path)
    img = img.resize((img_width, img_height))
    img = tf.keras.preprocessing.image.img_to_array(img)
    img = img / 255.0
    img = tf.expand_dims(img, axis=0)
    pred = densenet121_model.predict(img)
    pred_label = class_names[np.argmax(pred)]
    folder_name = os.path.basename(os.path.dirname(image_path))
    plt.imshow(img[0])
    if (pred_label != folder_name):
        plt.title('Pred: ' + pred_label + ' Actl: ' + folder_name, color = 'red')
        negative+=1
    else:
        plt.title('Pred: ' + pred_label + ' Actl: ' + folder_name, color = 'green')
        positive+=1
   
    plt.axis('off')
    plt.show() 
print('False: '+ str(negative) + '\nTrue: ' + str(positive))
