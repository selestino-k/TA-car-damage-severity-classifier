# %%
import os
import tensorflow as tf

train_dir = 'data3a/training' 
val_dir = 'data3a/validation'

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications.inception_v3 import preprocess_input

train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    shear_range=0.2,
    zoom_range=0.1,
    horizontal_flip=True,
    vertical_flip=True,
)

val_datagen = ImageDataGenerator(rescale=1./255)

# %%
img_width, img_height = 150, 150
batch_size = 16

# %%
train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(img_width, img_height),
    batch_size=batch_size,
    class_mode='categorical'
)

val_generator = val_datagen.flow_from_directory(
    val_dir,
    target_size=(img_width, img_height),
    batch_size=batch_size,
    class_mode='categorical'
)
# Out:
# Found 1383 images belonging to 3 classes.
# Found 248 images belonging to 3 classes.

# %%
from tensorflow.keras.applications import InceptionV3
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Flatten, Dense, Dropout

inceptionv3_model = Sequential()
pretrained_model = InceptionV3(
    include_top=False,
    input_shape=(img_width, img_height, 3),
    pooling='max',
    classes=3,
    weights='imagenet'
)
for layer in pretrained_model.layers:
    layer.trainable=False
    
inceptionv3_model.add(pretrained_model)

inceptionv3_model.add(Flatten())
inceptionv3_model.add(Dense(512, activation='relu',))
# minor, moderate, and severe (3)
inceptionv3_model.add(Dense(3, activation='softmax'))

# %%
inceptionv3_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  inception_v3 (Functional)   (None, 2048)              21802784
#
#  flatten (Flatten)           (None, 2048)              0
#
#  dense (Dense)               (None, 512)               1049088
#
#  dense_1 (Dense)             (None, 3)                 1539
#
# =================================================================
# Total params: 22853411 (87.18 MB)
# Trainable params: 1050627 (4.01 MB)
# Non-trainable params: 21802784 (83.17 MB)
# _________________________________________________________________

# %%
#Model compile
from tensorflow.keras.optimizers import Adam
opt = Adam(learning_rate=0.001)

inceptionv3_model.compile(optimizer=opt, loss='categorical_crossentropy', metrics=['accuracy'])

# %%
from tensorflow.keras.callbacks import CSVLogger

# Define the CSVLogger

log_folder = "traininglog"
log_file_path = f"{log_folder}/inceptionv3_training_log.csv"

csv_logger = CSVLogger(log_file_path, append=True)

# %%
#Model Train 
set_epoch=50

import time 
start_time = time.time()

# Train the model and pass the CSVLogger as a callback
history = inceptionv3_model.fit(train_generator, epochs=set_epoch, validation_data=val_generator,callbacks=[csv_logger])

end_time = time.time()
elapsed_time = end_time - start_time

print(f"Total training time: {elapsed_time:.2f} seconds")
# Out:
# Epoch 1/50
# 87/87 [==============================] - 29s 332ms/step - loss: 0.9579 - accuracy: 0.5423 - val_loss: 0.7625 - val_accuracy: 0.6411
# Epoch 2/50
# 87/87 [==============================] - 21s 236ms/step - loss: 0.9180 - accuracy: 0.5611 - val_loss: 0.7383 - val_accuracy: 0.6452
# Epoch 3/50
# 87/87 [==============================] - 18s 212ms/step - loss: 0.9291 - accuracy: 0.5293 - val_loss: 0.7698 - val_accuracy: 0.6492
# Epoch 4/50
# 87/87 [==============================] - 23s 268ms/step - loss: 0.9272 - accuracy: 0.5488 - val_loss: 0.7765 - val_accuracy: 0.6734
# Epoch 5/50
# 87/87 [==============================] - 26s 299ms/step - loss: 0.8500 - accuracy: 0.5951 - val_loss: 0.7763 - val_accuracy: 0.6573
# Epoch 6/50
# 87/87 [==============================] - 27s 305ms/step - loss: 0.8406 - accuracy: 0.6088 - val_loss: 0.7146 - val_accuracy: 0.6855
# Epoch 7/50
# 87/87 [==============================] - 25s 285ms/step - loss: 0.8528 - accuracy: 0.5893 - val_loss: 0.7345 - val_accuracy: 0.6815
# Epoch 8/50
# 87/87 [==============================] - 22s 250ms/step - loss: 0.8218 - accuracy: 0.6124 - val_loss: 0.7054 - val_accuracy: 0.6613
# Epoch 9/50
# 87/87 [==============================] - 23s 268ms/step - loss: 0.8223 - accuracy: 0.6081 - val_loss: 0.7107 - val_accuracy: 0.7056
# Epoch 10/50
# 87/87 [==============================] - 19s 221ms/step - loss: 0.8492 - accuracy: 0.6132 - val_loss: 0.7334 - val_accuracy: 0.6734
# Epoch 11/50
# 87/87 [==============================] - 19s 220ms/step - loss: 0.7942 - accuracy: 0.6291 - val_loss: 0.6894 - val_accuracy: 0.7016
# Epoch 12/50
# 87/87 [==============================] - 19s 220ms/step - loss: 0.8158 - accuracy: 0.6016 - val_loss: 0.7700 - val_accuracy: 0.6855
# Epoch 13/50
# 87/87 [==============================] - 19s 219ms/step - loss: 0.8268 - accuracy: 0.6103 - val_loss: 0.6823 - val_accuracy: 0.7540
# Epoch 14/50
# 87/87 [==============================] - 19s 221ms/step - loss: 0.8129 - accuracy: 0.6161 - val_loss: 0.7490 - val_accuracy: 0.6815
# Epoch 15/50
# 87/87 [==============================] - 19s 219ms/step - loss: 0.8254 - accuracy: 0.6161 - val_loss: 0.7314 - val_accuracy: 0.6774
# Epoch 16/50
# 87/87 [==============================] - 19s 220ms/step - loss: 0.8326 - accuracy: 0.5936 - val_loss: 0.7521 - val_accuracy: 0.6815
# Epoch 17/50
# 87/87 [==============================] - 19s 220ms/step - loss: 0.7965 - accuracy: 0.6392 - val_loss: 0.7292 - val_accuracy: 0.7056
# Epoch 18/50
# 87/87 [==============================] - 22s 257ms/step - loss: 0.7857 - accuracy: 0.6240 - val_loss: 0.7035 - val_accuracy: 0.7339
# Epoch 19/50
# 87/87 [==============================] - 24s 277ms/step - loss: 0.7953 - accuracy: 0.6168 - val_loss: 0.6964 - val_accuracy: 0.6774
# Epoch 20/50
# 87/87 [==============================] - 22s 248ms/step - loss: 0.7814 - accuracy: 0.6414 - val_loss: 0.8405 - val_accuracy: 0.5726
# Epoch 21/50
# 87/87 [==============================] - 24s 273ms/step - loss: 0.8056 - accuracy: 0.6233 - val_loss: 0.7037 - val_accuracy: 0.7339
# Epoch 22/50
# 87/87 [==============================] - 23s 262ms/step - loss: 0.7735 - accuracy: 0.6435 - val_loss: 0.6761 - val_accuracy: 0.7218
# Epoch 23/50
# 87/87 [==============================] - 19s 222ms/step - loss: 0.7772 - accuracy: 0.6479 - val_loss: 0.6845 - val_accuracy: 0.7097
# Epoch 24/50
# 87/87 [==============================] - 19s 223ms/step - loss: 0.7849 - accuracy: 0.6370 - val_loss: 0.7080 - val_accuracy: 0.7218
# Epoch 25/50
# 87/87 [==============================] - 20s 224ms/step - loss: 0.7843 - accuracy: 0.6377 - val_loss: 0.6684 - val_accuracy: 0.7056
# Epoch 26/50
# 87/87 [==============================] - 19s 221ms/step - loss: 0.7919 - accuracy: 0.6312 - val_loss: 0.7586 - val_accuracy: 0.6532
# Epoch 27/50
# 87/87 [==============================] - 19s 221ms/step - loss: 0.7619 - accuracy: 0.6471 - val_loss: 0.6667 - val_accuracy: 0.7177
# Epoch 28/50
# 87/87 [==============================] - 19s 223ms/step - loss: 0.7828 - accuracy: 0.6320 - val_loss: 0.7309 - val_accuracy: 0.6774
# Epoch 29/50
# 87/87 [==============================] - 19s 222ms/step - loss: 0.7644 - accuracy: 0.6450 - val_loss: 0.7104 - val_accuracy: 0.6774
# Epoch 30/50
# 87/87 [==============================] - 19s 221ms/step - loss: 0.7834 - accuracy: 0.6529 - val_loss: 0.6914 - val_accuracy: 0.6895
# Epoch 31/50
# 87/87 [==============================] - 19s 223ms/step - loss: 0.7958 - accuracy: 0.6218 - val_loss: 0.6706 - val_accuracy: 0.7258
# Epoch 32/50
# 87/87 [==============================] - 19s 222ms/step - loss: 0.7745 - accuracy: 0.6573 - val_loss: 0.6982 - val_accuracy: 0.7097
# Epoch 33/50
# 87/87 [==============================] - 19s 223ms/step - loss: 0.7608 - accuracy: 0.6537 - val_loss: 0.6741 - val_accuracy: 0.6976
# Epoch 34/50
# 87/87 [==============================] - 22s 254ms/step - loss: 0.7699 - accuracy: 0.6435 - val_loss: 0.7062 - val_accuracy: 0.6895
# Epoch 35/50
# 87/87 [==============================] - 23s 262ms/step - loss: 0.7613 - accuracy: 0.6464 - val_loss: 0.7752 - val_accuracy: 0.6250
# Epoch 36/50
# 87/87 [==============================] - 19s 220ms/step - loss: 0.7539 - accuracy: 0.6500 - val_loss: 0.7385 - val_accuracy: 0.6653
# Epoch 37/50
# 87/87 [==============================] - 19s 221ms/step - loss: 0.7773 - accuracy: 0.6377 - val_loss: 0.6960 - val_accuracy: 0.7056
# Epoch 38/50
# 87/87 [==============================] - 19s 221ms/step - loss: 0.7598 - accuracy: 0.6522 - val_loss: 0.6496 - val_accuracy: 0.7218
# Epoch 39/50
# 87/87 [==============================] - 19s 221ms/step - loss: 0.7697 - accuracy: 0.6450 - val_loss: 0.7661 - val_accuracy: 0.6532
# Epoch 40/50
# 87/87 [==============================] - 19s 221ms/step - loss: 0.7692 - accuracy: 0.6399 - val_loss: 0.6601 - val_accuracy: 0.6976
# Epoch 41/50
# 87/87 [==============================] - 19s 223ms/step - loss: 0.7944 - accuracy: 0.6262 - val_loss: 0.7018 - val_accuracy: 0.7056
# Epoch 42/50
# 87/87 [==============================] - 22s 248ms/step - loss: 0.7976 - accuracy: 0.6291 - val_loss: 0.7377 - val_accuracy: 0.6694
# Epoch 43/50
# 87/87 [==============================] - 24s 279ms/step - loss: 0.7719 - accuracy: 0.6471 - val_loss: 0.6885 - val_accuracy: 0.7016
# Epoch 44/50
# 87/87 [==============================] - 24s 280ms/step - loss: 0.7543 - accuracy: 0.6537 - val_loss: 0.7067 - val_accuracy: 0.7016
# Epoch 45/50
# 87/87 [==============================] - 24s 270ms/step - loss: 0.7534 - accuracy: 0.6443 - val_loss: 0.7603 - val_accuracy: 0.6734
# Epoch 46/50
# 87/87 [==============================] - 23s 259ms/step - loss: 0.7445 - accuracy: 0.6565 - val_loss: 0.6914 - val_accuracy: 0.7056
# Epoch 47/50
# 87/87 [==============================] - 24s 276ms/step - loss: 0.7476 - accuracy: 0.6551 - val_loss: 0.9228 - val_accuracy: 0.5887
# Epoch 48/50
# 87/87 [==============================] - 21s 241ms/step - loss: 0.7635 - accuracy: 0.6370 - val_loss: 0.8061 - val_accuracy: 0.6129
# Epoch 49/50
# 87/87 [==============================] - 20s 224ms/step - loss: 0.7828 - accuracy: 0.6435 - val_loss: 0.7228 - val_accuracy: 0.6573
# Epoch 50/50
# 87/87 [==============================] - 22s 257ms/step - loss: 0.7483 - accuracy: 0.6667 - val_loss: 0.6624 - val_accuracy: 0.7177
# Total training time: 1060.35 seconds

# %%
import matplotlib.pyplot as plt

# loss
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# accuracy
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
import numpy as np
val_images, val_labels = [], []
class_names = sorted(train_generator.class_indices.keys())
for i in range(len(val_generator)):
    images, labels = val_generator[i]
    val_images.extend(images)
    val_labels.extend(np.argmax(labels, axis=1))

val_images = np.array(val_images)
val_labels = np.array(val_labels)

predictions = inceptionv3_model.predict(val_images)

y_pred = np.argmax(predictions, axis=1)
y_true = val_labels

from sklearn.metrics import confusion_matrix, classification_report

confusion_matrix = confusion_matrix(y_true, y_pred)
fig, ax = plt.subplots()
cax = ax.matshow(confusion_matrix, cmap='Reds')
    
cbar = fig.colorbar(cax)

ax.set_xlabel('predicted') #predicted
ax.set_ylabel('actual') #actual

ax.set_xticklabels([''] + ['minor', 'moderate', 'severe'], rotation=45) #predicted
ax.set_yticklabels([''] + ['minor', 'moderate', 'severe']) #actual

for i in range(confusion_matrix.shape[0]):
    for j in range(confusion_matrix.shape[1]):
        ax.text(j, i, str(confusion_matrix[i, j]), ha='center', va='center')
print('Confusion Matrix:')

plt.show()

report = classification_report(y_true, y_pred, target_names=class_names)
print('Classification Report:')
print(report)

# %%
val_dir = 'data3a/validation'
class_names = ["01-minor", "02-moderate", "03-severe"]

image_paths = []
for class_name in class_names:
    folder_path = os.path.join(val_dir, class_name)
    for filename in os.listdir(folder_path):
        if filename.endswith(".jpg") or filename.endswith(".png"):
            image_paths.append(os.path.join(folder_path, filename))
negative = 0
positive = 0
for image_path in image_paths:
    img = tf.keras.preprocessing.image.load_img(image_path)
    img = img.resize((img_width, img_height))
    img = tf.keras.preprocessing.image.img_to_array(img)
    img = img / 255.0
    img = tf.expand_dims(img, axis=0)
    pred = inceptionv3_model.predict(img)
    pred_label = class_names[np.argmax(pred)]
    folder_name = os.path.basename(os.path.dirname(image_path))
    plt.imshow(img[0])
    if (pred_label != folder_name):
        plt.title('Pred: ' + pred_label + ' Actl: ' + folder_name, color = 'red')
        negative+=1
    else:
        plt.title('Pred: ' + pred_label + ' Actl: ' + folder_name, color = 'green')
        positive+=1
   
    plt.axis('off')
    plt.show() 
print('False: '+ str(negative) + '\nTrue: ' + str(positive))

# %%
inceptionv3_model.save('models/inceptionv3-model-bs16-ep50-dense512.keras')
print('model saved')
