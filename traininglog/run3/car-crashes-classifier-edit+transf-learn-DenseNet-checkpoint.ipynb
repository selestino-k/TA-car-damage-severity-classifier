# %%
import os
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator

import matplotlib.pyplot as plt

import time 

from tensorflow.keras.models import Sequential
from tensorflow.keras.applications import DenseNet121
from tensorflow.keras.layers import Flatten, Dense, Dropout

# %%
train_dir = 'data3a/training' 
val_dir = 'data3a/validation'

# %%
img_width, img_height = 150, 150

# %%
epoch = 50
batch_size=16

# %%
train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    shear_range=0.2,
    zoom_range=0.1,
    horizontal_flip=True,
    vertical_flip=True
)

val_datagen = ImageDataGenerator(rescale=1./255)

# %%
train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(img_width, img_height),
    batch_size=batch_size,
    class_mode='categorical'
)

val_generator = val_datagen.flow_from_directory(
    val_dir,
    target_size=(img_width, img_height),
    batch_size=batch_size,
    class_mode='categorical'
)
# Out:
# Found 1383 images belonging to 3 classes.
# Found 248 images belonging to 3 classes.

# %%
densenet121_model = Sequential()
pretrained_model = DenseNet121(
    include_top=False,
    input_shape=(img_width, img_height, 3),
    pooling='max',
    classes=3,
    weights='imagenet'
)
for layer in pretrained_model.layers:
    layer.trainable=False
    
densenet121_model.add(pretrained_model)
densenet121_model.add(Flatten())
densenet121_model.add(Dense(512, activation='relu'))
# minor moderate and severe (3)
densenet121_model.add(Dense(3, activation='softmax'))

# %%
#Model compile
densenet121_model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
from tensorflow.keras.callbacks import CSVLogger

# Define the CSVLogger

log_folder = "traininglog"
log_file_path = f"{log_folder}/densenet121_training_log.csv"

csv_logger = CSVLogger(log_file_path, append=True)

# %%
set_epoch=50
#Model Train 
start_time = time.time()

# Train the model and pass the CSVLogger as a callback
history = densenet121_model.fit(train_generator, epochs=set_epoch, validation_data=val_generator,callbacks=[csv_logger])

end_time = time.time()
elapsed_time = end_time - start_time

print(f"Total training time: {elapsed_time:.2f} seconds")
# Out:
# Epoch 1/50
# 87/87 [==============================] - 68s 703ms/step - loss: 1.9175 - accuracy: 0.4722 - val_loss: 1.1109 - val_accuracy: 0.6048
# Epoch 2/50
# 87/87 [==============================] - 58s 671ms/step - loss: 1.0281 - accuracy: 0.5611 - val_loss: 0.8998 - val_accuracy: 0.6008
# Epoch 3/50
# 87/87 [==============================] - 58s 668ms/step - loss: 0.8954 - accuracy: 0.5893 - val_loss: 0.8723 - val_accuracy: 0.5645
# Epoch 4/50
# 87/87 [==============================] - 60s 689ms/step - loss: 0.8366 - accuracy: 0.6067 - val_loss: 0.7488 - val_accuracy: 0.6613
# Epoch 5/50
# 87/87 [==============================] - 60s 693ms/step - loss: 0.8171 - accuracy: 0.6168 - val_loss: 0.7342 - val_accuracy: 0.6613
# Epoch 6/50
# 87/87 [==============================] - 61s 699ms/step - loss: 0.7829 - accuracy: 0.6312 - val_loss: 0.8220 - val_accuracy: 0.6089
# Epoch 7/50
# 87/87 [==============================] - 60s 690ms/step - loss: 0.7780 - accuracy: 0.6457 - val_loss: 0.7141 - val_accuracy: 0.6694
# Epoch 8/50
# 87/87 [==============================] - 61s 698ms/step - loss: 0.7885 - accuracy: 0.6349 - val_loss: 0.7449 - val_accuracy: 0.6613
# Epoch 9/50
# 87/87 [==============================] - 61s 702ms/step - loss: 0.7711 - accuracy: 0.6406 - val_loss: 0.7925 - val_accuracy: 0.6250
# Epoch 10/50
# 87/87 [==============================] - 61s 697ms/step - loss: 0.7684 - accuracy: 0.6334 - val_loss: 0.7119 - val_accuracy: 0.6694
# Epoch 11/50
# 87/87 [==============================] - 58s 665ms/step - loss: 0.7501 - accuracy: 0.6551 - val_loss: 0.7348 - val_accuracy: 0.6653
# Epoch 12/50
# 87/87 [==============================] - 55s 634ms/step - loss: 0.7098 - accuracy: 0.6768 - val_loss: 0.9058 - val_accuracy: 0.5363
# Epoch 13/50
# 87/87 [==============================] - 60s 692ms/step - loss: 0.7413 - accuracy: 0.6594 - val_loss: 0.8860 - val_accuracy: 0.5645
# Epoch 14/50
# 87/87 [==============================] - 60s 686ms/step - loss: 0.7350 - accuracy: 0.6602 - val_loss: 0.7316 - val_accuracy: 0.6452
# Epoch 15/50
# 87/87 [==============================] - 59s 681ms/step - loss: 0.7483 - accuracy: 0.6587 - val_loss: 0.7338 - val_accuracy: 0.6492
# Epoch 16/50
# 87/87 [==============================] - 60s 688ms/step - loss: 0.7088 - accuracy: 0.6623 - val_loss: 0.6828 - val_accuracy: 0.6653
# Epoch 17/50
# 87/87 [==============================] - 58s 667ms/step - loss: 0.7156 - accuracy: 0.6768 - val_loss: 0.7871 - val_accuracy: 0.6331
# Epoch 18/50
# 87/87 [==============================] - 60s 691ms/step - loss: 0.7105 - accuracy: 0.6797 - val_loss: 0.7577 - val_accuracy: 0.6532
# Epoch 19/50
# 87/87 [==============================] - 61s 699ms/step - loss: 0.7267 - accuracy: 0.6573 - val_loss: 0.7542 - val_accuracy: 0.6290
# Epoch 20/50
# 87/87 [==============================] - 61s 701ms/step - loss: 0.7256 - accuracy: 0.6768 - val_loss: 0.8237 - val_accuracy: 0.6290
# Epoch 21/50
# 87/87 [==============================] - 61s 697ms/step - loss: 0.6916 - accuracy: 0.6855 - val_loss: 0.7616 - val_accuracy: 0.6250
# Epoch 22/50
# 87/87 [==============================] - 61s 703ms/step - loss: 0.7205 - accuracy: 0.6753 - val_loss: 0.7240 - val_accuracy: 0.6613
# Epoch 23/50
# 87/87 [==============================] - 61s 698ms/step - loss: 0.6925 - accuracy: 0.6833 - val_loss: 0.7489 - val_accuracy: 0.6290
# Epoch 24/50
# 87/87 [==============================] - 62s 708ms/step - loss: 0.6963 - accuracy: 0.6768 - val_loss: 0.7334 - val_accuracy: 0.6411
# Epoch 25/50
# 87/87 [==============================] - 61s 699ms/step - loss: 0.6872 - accuracy: 0.6999 - val_loss: 0.7339 - val_accuracy: 0.6653
# Epoch 26/50
# 87/87 [==============================] - 61s 700ms/step - loss: 0.6730 - accuracy: 0.6949 - val_loss: 0.7363 - val_accuracy: 0.6734
# Epoch 27/50
# 87/87 [==============================] - 60s 693ms/step - loss: 0.6792 - accuracy: 0.6956 - val_loss: 0.6987 - val_accuracy: 0.6895
# Epoch 28/50
# 87/87 [==============================] - 60s 686ms/step - loss: 0.5890 - accuracy: 0.7397 - val_loss: 0.9050 - val_accuracy: 0.6089
# Epoch 47/50
# 87/87 [==============================] - 60s 685ms/step - loss: 0.6052 - accuracy: 0.7216 - val_loss: 0.7851 - val_accuracy: 0.6452
# Epoch 48/50
# 87/87 [==============================] - 60s 686ms/step - loss: 0.5958 - accuracy: 0.7469 - val_loss: 0.9198 - val_accuracy: 0.6048
# Epoch 49/50
# 87/87 [==============================] - 59s 684ms/step - loss: 0.5821 - accuracy: 0.7491 - val_loss: 0.8332 - val_accuracy: 0.6290
# Epoch 50/50
# 87/87 [==============================] - 60s 684ms/step - loss: 0.5831 - accuracy: 0.7397 - val_loss: 0.8065 - val_accuracy: 0.6492
# Total training time: 3010.52 seconds

# %%
import matplotlib.pyplot as plt
# loss
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# accuracy
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()
from sklearn.metrics import f1_score
# # f1 score
# plt.plot(history.history['f1_score'], label='Training F1 Score')
# plt.plot(history.history['val_f1_score'], label='Validation F1 Score')
# plt.xlabel('Epochs')
# plt.ylabel('F1 Score')
# plt.legend()
# plt.show()

# %%
import numpy as np
val_images, val_labels = [], []
class_names = sorted(train_generator.class_indices.keys())
for i in range(len(val_generator)):
    images, labels = val_generator[i]
    val_images.extend(images)
    val_labels.extend(np.argmax(labels, axis=1))


val_images = np.array(val_images)
val_labels = np.array(val_labels)

predictions = densenet121_model.predict(val_images)



from sklearn.metrics import confusion_matrix, classification_report

y_pred = np.argmax(predictions, axis=1)
y_true = val_labels

confusion_matrix = confusion_matrix(y_true, y_pred)
fig, ax = plt.subplots()
cax = ax.matshow(confusion_matrix, cmap='Reds')

cbar = fig.colorbar(cax)

ax.set_xlabel('predicted') #predicted
ax.set_ylabel('actual') #actual

ax.set_xticklabels([''] + ['minor', 'moderate', 'severe'], rotation=45) #predicted
ax.set_yticklabels([''] + ['minor', 'moderate', 'severe']) #actual

for i in range(confusion_matrix.shape[0]):
    for j in range(confusion_matrix.shape[1]):
        ax.text(j, i, str(confusion_matrix[i, j]), ha='center', va='center')
print('Confusion Matrix:')

plt.show()



report = classification_report(y_true, y_pred, target_names=class_names)
print('Classification Report:')
print(report)

# %%
densenet_model.save('densenet121-model.keras')
print('model saved')

# %%
val_dir = 'data3a/validation'
class_names = ["01-minor", "02-moderate", "03-severe"]

image_paths = []
for class_name in class_names:
    folder_path = os.path.join(val_dir, class_name)
    for filename in os.listdir(folder_path):
        if filename.endswith(".jpg") or filename.endswith(".png"):
            image_paths.append(os.path.join(folder_path, filename))
negative = 0
positive = 0
for image_path in image_paths:
    img = tf.keras.preprocessing.image.load_img(image_path)
    img = img.resize((img_width, img_height))
    img = tf.keras.preprocessing.image.img_to_array(img)
    img = img / 255.0
    img = tf.expand_dims(img, axis=0)
    pred = densenet121_model.predict(img)
    pred_label = class_names[np.argmax(pred)]
    folder_name = os.path.basename(os.path.dirname(image_path))
    plt.imshow(img[0])
    if (pred_label != folder_name):
        plt.title('Pred: ' + pred_label + ' Actl: ' + folder_name, color = 'red')
        negative+=1
    else:
        plt.title('Pred: ' + pred_label + ' Actl: ' + folder_name, color = 'green')
        positive+=1
   
    plt.axis('off')
    plt.show() 
print('False: '+ str(negative) + '\nTrue: ' + str(positive))
